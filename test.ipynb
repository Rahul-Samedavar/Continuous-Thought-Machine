# %%
from inference import *

# %%
filepath = r"dataset\train\pituitary\Tr-pi_0014.jpg"


inference(filepath, model)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
# Saving GIF to output\Tr-pi_0014.jpg_viz.gif...
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="400" height="450" style="image-rendering:auto; object-fit:cover;" src="data:image/gif;base64,..."/></td></tr></table>
